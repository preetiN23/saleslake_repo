# %%
# %sql
truncate table intellibi_catlog.intellibi_bronze.fMonthlySales;
truncate table intellibi_catlog.intellibi_silver.fMonthlySales;
truncate table intellibi_catlog.intellibi_gold.fMonthlySales;

# %%
# %sql
select count(*) from intellibi_catlog.intellibi_bronze.fMonthlySales;

# %%
# %sql

select count(*) from intellibi_catlog.intellibi_silver.fMonthlySales;

# %%
# %sql
select count(*) from intellibi_catlog.intellibi_gold.fMonthlySales;

# %%
15 -- > 15 --- > 30

# %%
# %sql
select * from intellibi_catlog.intellibi_bronze.fMonthlySales;

# %%
# %sql
SELECT * FROM saleslake_prd.bronze_prd.rawInvoice;

# %%
# %sql
SELECT * FROM saleslake_prd.silver_prd.cleanedinvoice;

# %%
# %sql
SELECT * FROM saleslake_prd.gold_prd.refinedinvoice;
