-- %%
CREATE OR REPLACE TABLE intellibi_catlog.intellibi_silver.cleanedMonthlySales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    ingest_ts timestamp
);

describe intellibi_catlog.intellibi_silver.cleanedMonthlySales;
-- describe history intellibi_catlog.intellibi_silver.cleanedMonthlySales;
SELECT * FROM intellibi_catlog.intellibi_silver.cleanedMonthlySales;
-- DROP TABLE intellibi_catlog.intellibi_bronze.dfMonthlySales;

DROP TABLE intellibi_catlog.intellibi_silver.fMonthlySales;

TRUNCATE TABLE intellibi_catlog.intellibi_silver.cleanedMonthlySales;


CREATE OR REPLACE TABLE intellibi_catlog.intellibi_silver.cleanedCustomer
(
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

-- describe intellibi_catlog.intellibi_silver.cleanedCustomer;
-- -- describe history intellibi_catlog.intellibi_silver.cleanedCustomer;
-- SELECT * FROM intellibi_catlog.intellibi_silver.cleanedCustomer;
-- -- DROP TABLE intellibi_catlog.intellibi_bronze.cleanedCustomer;



-- DROP TABLE intellibi_catlog.intellibi_silver.cleanedCustomer;

-- TRUNCATE TABLE intellibi_catlog.intellibi_silver.cleanedCustomer;
SELECT * FROM intellibi_catlog.intellibi_silver.cleanedCustomer;
