# %%
# %sql
# SELECT * FROM intellibi_catlog.intellibi_bronzE.fMonthlySales;

# %%
# %sql
# SELECT * FROM intellibi_catlog.intellibi_silver.fMonthlySales;

# %%
# %sql 
INSERT INTO intellibi_catlog.intellibi_silver.fMonthlySales
SELECT * FROM intellibi_catlog.intellibi_bronze.fMonthlySales
-- WHERE CURRENT_TIMESTAMP() > ingest_ts;

-- COPY INTO intellibi_catlog.intellibi_silver.fMonthlySales
-- FROM intellibi_catlog.intellibi_bronze.fMonthlySales;
--

15 -- 14-05--2026

# %%
# %sql
SELECT * FROM intellibi_catlog.intellibi_SILVER.fMonthlySales;
