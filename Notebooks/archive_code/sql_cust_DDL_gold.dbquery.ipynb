-- %%
-- SELECT * FROM intellibi_catlog.intellibi_gold.RefinedCustomer;

CREATE OR REPLACE TABLE intellibi_catlog.intellibi_gold.RefinedCustomer
(
    customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp,
    is_active string,
    rec_version	int, 
    start_effective_ts	timestamp,
    end_effective_ts timestamp

);


-- intellibi_catlog.intellibi_silver.cleanedmonthlysales
-- describe intellibi_catlog.intellibi_silver.cleanedMonthlySales;
-- -- describe history intellibi_catlog.intellibi_silver.cleanedMonthlySales;
-- SELECT * FROM intellibi_catlog.intellibi_silver.cleanedMonthlySales;


1001	AARAV SHARMA	AARAV.SHARMA@EXAMPLE.COM	+91-9876500001	12 MG ROAD	PUNE	MH	IN	411001	RETAIL
-- -- DROP TABLE intellibi_catlog.intellibi_bronze.dfMonthlySales;



-- DROP TABLE intellibi_catlog.intellibi_silver.fMonthlySales;

-- TRUNCATE TABLE intellibi_catlog.intellibi_silver.cleanedMonthlySales;

SELECT * FROM intellibi_catlog.intellibi_gold.RefinedCustomer;
TRUNCATE TABLE intellibi_catlog.intellibi_gold.RefinedCustomer;

INSERT INTO intellibi_catlog.intellibi_gold.RefinedCustomer
(customer_id,customer_name,email,phone,address,city,state,country,zip_code,segment,
is_active,rec_version,start_effective_ts,end_effective_ts)
VALUES
(
    1001,'AARAV SHARMA','AARAV.SHARMA@EXAMPLE.COM','+91-9876500001','12 MG ROAD','PUNE','MH','IN','411001','RETAIL',
    'Y',1,current_timestamp(),to_date('3099-12-31','yyyy-mm-dd')
);

INSERT INTO intellibi_catlog.intellibi_gold.RefinedCustomer
(customer_id,customer_name,email,phone,address,city,state,country,zip_code,segment,
is_active,rec_version,start_effective_ts,end_effective_ts)
VALUES
(
    1002,'BHAVNA IYER','BHAVNA.IYER@GMAIL.COM','+91-9876500002','45 ANNA NAGAR','CHENNAI','TN','IN','600040','RETAIL',
    'Y',1,current_timestamp(),to_date('3099-12-31','yyyy-mm-dd')
);

TRUNCATE TABLE  intellibi_catlog.intellibi_bronze.rawCustomer;
TRUNCATE TABLE intellibi_catlog.intellibi_silver.cleanedCustomer;
TRUNCATE TABLE intellibi_catlog.intellibi_gold.RefinedCustomer; 

select count(*) from  intellibi_catlog.intellibi_bronze.rawCustomer;
select count(*) from  intellibi_catlog.intellibi_silver.cleanedCustomer;
select count(*) from  intellibi_catlog.intellibi_gold.RefinedCustomer; 


-- SCD Type-1  : % sql ---> MERGE STATEMENT
-- SCD Type-2  : % sql ---> MERGE STATEMENT


-- select * from  intellibi_catlog.intellibi_gold.RefinedCustomer ORDER BY customer_id ,rec_version;

-- 1002	BHAVNA IYER	BHAVNA.IYER@EXAMPLE.COM	+91-9876500002	45 ANNA NAGAR	CHENNAI	TN	IN	600040	RETAIL


-- SELECT * FROM intellibi_catlog.intellibi_gold.RefinedCustomer;

-- -- SELECT * FROM intellibi_catlog.int

-- 1001	AARAV SHARMA	AARAV.SHARMA@EXAMPLE.COM	+91-9876500001	12 MG ROAD	PUNE	MH	IN	411001	RETAIL


-- intellibi_catlog.intellibi_gold.RefinedCustomer;

-- SCD Type-1  : % pyton ----> MERGE STATEMENT
-- SCD Type-2  : % python ---> MERGE STATEMENT
