# %%
# ---------------------------- vol_saleslake_src_files_dev -------------------
# -------- manual_discount --------------------
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/manual_discount/")
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_qa/bronze_qa/vol_saleslake_src_files_qa/manual_discount/")
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_prd/bronze_prd/vol_saleslake_src_files_prd/manual_discount/")
#------------ daily_customer --------------------------
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/daily_customer/")
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_qa/bronze_qa/vol_saleslake_src_files_qa/daily_customer/")
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_prd/bronze_prd/vol_saleslake_src_files_prd/daily_customer/")
#-------------- daily_sales -------------------
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/daily_sales/")
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_qa/bronze_qa/vol_saleslake_src_files_qa/daily_sales/")
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_prd/bronze_prd/vol_saleslake_src_files_prd/daily_sales/")

# ---------------------------- vol_saleslake_archive_files_dev -------------------
# -------- manual_discount --------------------
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/bronze_dev/vol_saleslake_archive_files_dev/manual_discount/")
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_qa/bronze_qa/vol_saleslake_archive_files_qa/manual_discount/")
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_prd/bronze_prd/vol_saleslake_archive_files_prd/manual_discount/")
#------------ daily_customer --------------------------
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/bronze_dev/vol_saleslake_archive_files_dev/daily_customer/")
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_qa/bronze_qa/vol_saleslake_archive_files_qa/daily_customer/")
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_prd/bronze_prd/vol_saleslake_archive_files_prd/daily_customer/")
#-------------- daily_sales -------------------
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/bronze_dev/vol_saleslake_archive_files_dev/daily_sales/")
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_qa/bronze_qa/vol_saleslake_archive_files_qa/daily_sales/")
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_prd/bronze_prd/vol_saleslake_archive_files_prd/daily_sales/")
