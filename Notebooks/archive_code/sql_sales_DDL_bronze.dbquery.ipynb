-- %%
CREATE OR REPLACE TABLE intellibi_catlog.intellibi_bronze.rawMonthlySales
(
    sale_id string , product string, category string, 
    quantity string , price string , 
    sale_date string , region string, 
    ingest_ts timestamp
);

describe intellibi_catlog.intellibi_bronze.rawMonthlySales;
describe history intellibi_catlog.intellibi_bronze.rawMonthlySales;
SELECT * FROM intellibi_catlog.intellibi_bronze.rawMonthlySales;
-- DROP TABLE intellibi_catlog.intellibi_bronze.dfMonthlySales;
DROP TABLE  intellibi_catlog.intellibi_bronze.rawMonthlySales;
