-- %%
TRUNCATE TABLE intellibi_catlog.intellibi_bronze.rawMonthlySales;
TRUNCATE TABLE intellibi_catlog.intellibi_silver.cleanedMonthlySales;
TRUNCATE TABLE intellibi_catlog.intellibi_gold.RefinedMonthlySales;


----------------------------------------------------------------------
SELECT * FROM  intellibi_catlog.intellibi_bronze.rawMonthlySales;
SELECT * FROM  intellibi_catlog.intellibi_silver.cleanedMonthlySales;
SELECT * FROM   intellibi_catlog.intellibi_gold.RefinedMonthlySales;


-----------------------

  SELECT * FROM intellibi_catlog.intellibi_silver.cleanedmonthlysales;
