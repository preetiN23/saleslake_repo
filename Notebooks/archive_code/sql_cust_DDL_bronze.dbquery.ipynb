-- %%
CREATE OR REPLACE TABLE intellibi_catlog.intellibi_bronze.rawCustomer
(
    customer_id string , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

-- customer_id,customer_name,email,phone,address,city,state,country,zip_code,segment
describe intellibi_catlog.intellibi_bronze.rawCustomer;
describe history intellibi_catlog.intellibi_bronze.rawCustomer;
SELECT * FROM intellibi_catlog.intellibi_bronze.rawCustomer;
-- DROP TABLE intellibi_catlog.intellibi_bronze.dfMonthlySales;
DROP TABLE  intellibi_catlog.intellibi_bronze.rawCustomer;
