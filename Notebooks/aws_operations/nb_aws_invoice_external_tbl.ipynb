# %%
# %sql
COPY INTO saleslake_dev.bronze_dev.rawInvoice
FROM (
    SELECT invoice_id,invoice_number,customer_id,invoice_date,due_date,subtotal_amount,discount_code,discount_amount,tax_amount,total_amount,payment_status,payment_method,payment_date,currency,region,store_id,channel,created_by,current_timestamp AS ingest_ts
    FROM 's3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/invoice/'
    )
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true')

# %%
# Show the full storage-credential definition Databricks holds
display(spark.sql("DESCRIBE STORAGE CREDENTIAL `s3-demo-credential`"))

# %%
# %sql
SELECT * FROM system.information_schema.storage_credentials 
WHERE storage_credential_name = 'saleslake-credential';

# %%
display(dbutils.fs.ls("s3://saleslake-748005667258-eu-north-1-an/"))
