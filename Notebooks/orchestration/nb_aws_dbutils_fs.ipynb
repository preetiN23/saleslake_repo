# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/source_files/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/source_files/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/source_files/")
# ---------------  
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/archive_files/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/archive_files/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/archive_files/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/bronze/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/silver/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/gold/")

dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/bronze/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/silver/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/gold/")

dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/bronze/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/silver/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/gold/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/source_files/bronze/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/source_files/silver/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/source_files/gold/")

dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/source_files/bronze/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/source_files/silver/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/source_files/gold/")

dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/source_files/bronze/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/source_files/silver/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/source_files/gold/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/source_files/invoice/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/source_files/invoice/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/source_files/invoice/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/source_files/region/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/source_files/region/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/source_files/region/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/bronze/invoice/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/silver/invoice/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/gold/invoice/")
#
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/bronze/invoice/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/silver/invoice/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/gold/invoice/")
#
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/bronze/invoice/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/silver/invoice/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/gold/invoice/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/source_files/region/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/source_files/region/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/source_files/region/")
#s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/delta_tables/bronze/region/

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/bronze/product/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/bronze/product/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/bronze/product/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/bronze/store/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/bronze/store/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/bronze/store/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/silver/region/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/silver/region/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/silver/region/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/silver/product/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/silver/product/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/silver/product/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/silver/store/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/silver/store/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/silver/store/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/silver/discount/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/silver/discount/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/silver/discount/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/gold/dim_region/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/gold/dim_region/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/gold/dim_region/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/gold/dim_product/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/gold/dim_product/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/gold/dim_product/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/gold/dim_store/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/gold/dim_store/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/gold/dim_store/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/gold/dim_discount/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/gold/dim_discount/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/gold/dim_discount/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/gold/dim_date/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/gold/dim_date/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/gold/dim_date/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/gold/fact_sales/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/gold/fact_sales/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/gold/fact_sales/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/gold/fact_invoice/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/gold/fact_invoice/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/gold/fact_invoice/")

# %%
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/discount/")
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/discount/")

dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/source_files/discount/")

# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/discount/")
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/discount/")

dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/source_files/discount/")

# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/discount/")
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/discount/")

dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/source_files/discount/")

# %%
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/store/")
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/store/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/source_files/store/")

# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/store/")
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/store/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/source_files/store/")

# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/store/")
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/store/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/source_files/store/")

# %%
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/product/")
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/product/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/source_files/product/")

# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/product/")
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/product/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/source_files/product/")

# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/product/")
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/product/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/source_files/product/")

# %%
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/region/")
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/dev/source_files/region/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/source_files/region/")

# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/region/")
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/qa/source_files/region/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/source_files/region/")

# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/region/")
# dbutils.fs.mkdirs("s3://saleslake-748005667258-eu-north-1-an/saleslake/prd/source_files/region/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/source_files/region/")

# %%
dbutils.fs.rm("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/source_files/invoice/bronze/")
dbutils.fs.rm("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/source_files/invoice/silver/")
dbutils.fs.rm("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/source_files/invoice/gold/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/bronze/discount/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/bronze/discount/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/bronze/discount/")

# %%
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/dev/delta_tables/gold/dim_invoice/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/qa/delta_tables/gold/dim_invoice/")
dbutils.fs.mkdirs("s3://saleslake-197180824086-eu-north-1-an/saleslake/prd/delta_tables/gold/dim_invoice/")
