-- %%
----------------------- 1. Bronze Tables -------------------------
------------ 1. Bronze Sales ---------------------

TRUNCATE TABLE saleslake_dev.bronze_dev.rawSales;
TRUNCATE TABLE saleslake_qa.bronze_qa.rawSales;
TRUNCATE TABLE saleslake_prd.bronze_prd.rawSales;

------------ 2. Bronze Customer ---------------------

TRUNCATE TABLE  saleslake_dev.bronze_dev.rawCustomer;
TRUNCATE TABLE  saleslake_qa.bronze_qa.rawCustomer;
TRUNCATE TABLE  saleslake_prd.bronze_prd.rawCustomer;

------------ 3. Bronze Discount ---------------------

TRUNCATE TABLE  saleslake_dev.bronze_dev.rawDiscount;
TRUNCATE TABLE  saleslake_qa.bronze_qa.rawDiscount;
TRUNCATE TABLE  saleslake_prd.bronze_prd.rawDiscount;

------------ 4. Bronze rawInvoice ---------------------

TRUNCATE TABLE  saleslake_dev.bronze_dev.rawInvoice;
TRUNCATE TABLE  saleslake_qa.bronze_qa.rawInvoice;
TRUNCATE TABLE  saleslake_prd.bronze_prd.rawInvoice;

------------ 5. Bronze rawRegion ---------------------

TRUNCATE TABLE  saleslake_dev.bronze_dev.rawRegion;
TRUNCATE TABLE  saleslake_qa.bronze_qa.rawRegion;
TRUNCATE TABLE  saleslake_prd.bronze_prd.rawRegion;

------------ 6. Bronze rawProduct ---------------------

TRUNCATE TABLE  saleslake_dev.bronze_dev.rawProduct;
TRUNCATE TABLE  saleslake_qa.bronze_qa.rawProduct;
TRUNCATE TABLE  saleslake_prd.bronze_prd.rawProduct;

------------ 7. Bronze rawStore ---------------------

TRUNCATE TABLE  saleslake_dev.bronze_dev.rawStore;
TRUNCATE TABLE  saleslake_qa.bronze_qa.rawStore;
TRUNCATE TABLE  saleslake_prd.bronze_prd.rawStore;

--------------------------------------------------------------------------------------------------------------
----------------------- 2. Silver Tables -------------------------
------------ 1. Silver Sales ---------------------

TRUNCATE TABLE  saleslake_dev.silver_dev.cleanedSales;
TRUNCATE TABLE  saleslake_qa.silver_qa.cleanedSales;
TRUNCATE TABLE  saleslake_prd.silver_prd.cleanedSales;

----------- 2. Silver Customer ---------------------

TRUNCATE TABLE saleslake_dev.silver_dev.cleanedCustomer;
TRUNCATE TABLE saleslake_qa.silver_qa.cleanedCustomer;
TRUNCATE TABLE saleslake_prd.silver_prd.cleanedCustomer;

----------- 3. Silver Invoice ---------------------

TRUNCATE TABLE saleslake_dev.silver_dev.cleanedInvoice;
TRUNCATE TABLE saleslake_qa.silver_qa.cleanedInvoice;
TRUNCATE TABLE saleslake_prd.silver_prd.cleanedInvoice;

----------- 4. Silver Region ---------------------

TRUNCATE TABLE saleslake_dev.silver_dev.cleanedRegion;
TRUNCATE TABLE saleslake_qa.silver_qa.cleanedRegion;
TRUNCATE TABLE saleslake_prd.silver_prd.cleanedRegion;

----------- 5. Silver Product ---------------------

TRUNCATE TABLE saleslake_dev.silver_dev.cleanedProduct;
TRUNCATE TABLE saleslake_qa.silver_qa.cleanedProduct;
TRUNCATE TABLE saleslake_prd.silver_prd.cleanedProduct;

----------- 6. Silver Store ---------------------

TRUNCATE TABLE saleslake_dev.silver_dev.cleanedStore;
TRUNCATE TABLE saleslake_qa.silver_qa.cleanedStore;
TRUNCATE TABLE saleslake_prd.silver_prd.cleanedStore;

---------- 7. Silver Discount ---------------------

TRUNCATE TABLE saleslake_dev.silver_dev.cleanedDiscount;
TRUNCATE TABLE saleslake_qa.silver_qa.cleanedDiscount;
TRUNCATE TABLE saleslake_prd.silver_prd.cleanedDiscount;

----------------------------------------------------------------------------------------------------
----------------------- 3. Gold Tables -------------------------
-----------1. Gold Sales ---------------------

TRUNCATE TABLE saleslake_dev.gold_dev.refinedSales;
TRUNCATE TABLE saleslake_qa.gold_qa.refinedSales;
TRUNCATE TABLE saleslake_prd.gold_prd.refinedSales;

-----------2. Gold Customer ---------------------

TRUNCATE TABLE saleslake_dev.gold_dev.refinedCustomer;
TRUNCATE TABLE saleslake_qa.gold_qa.refinedCustomer;
TRUNCATE TABLE saleslake_prd.gold_prd.refinedCustomer;

-----------3. Gold Invoice ---------------------

TRUNCATE TABLE saleslake_dev.gold_dev.refinedInvoice;
TRUNCATE TABLE saleslake_qa.gold_qa.refinedInvoice;
TRUNCATE TABLE saleslake_prd.gold_prd.refinedInvoice;

-----------4. Gold dim_region ---------------------

TRUNCATE TABLE saleslake_dev.gold_dev.dim_region;
TRUNCATE TABLE saleslake_qa.gold_qa.dim_region;
TRUNCATE TABLE saleslake_prd.gold_prd.dim_region;

-----------5. Gold dim_product ---------------------

TRUNCATE TABLE saleslake_dev.gold_dev.dim_product;
TRUNCATE TABLE saleslake_qa.gold_qa.dim_product;
TRUNCATE TABLE saleslake_prd.gold_prd.dim_product;

-----------6. Gold dim_store ---------------------

TRUNCATE TABLE saleslake_dev.gold_dev.dim_store;
TRUNCATE TABLE saleslake_qa.gold_qa.dim_store;
TRUNCATE TABLE saleslake_prd.gold_prd.dim_store;

-----------7. Gold dim_discount ---------------------

TRUNCATE TABLE saleslake_dev.gold_dev.dim_discount;
TRUNCATE TABLE saleslake_qa.gold_qa.dim_discount;
TRUNCATE TABLE saleslake_prd.gold_prd.dim_discount;

-----------8. Gold fact_sales ---------------------

TRUNCATE TABLE saleslake_dev.gold_dev.fact_sales;
TRUNCATE TABLE saleslake_qa.gold_qa.fact_sales;
TRUNCATE TABLE saleslake_prd.gold_prd.fact_sales;

-----------9. Gold fact_invoice ---------------------

TRUNCATE TABLE saleslake_dev.gold_dev.fact_invoice;
TRUNCATE TABLE saleslake_qa.gold_qa.fact_invoice;
TRUNCATE TABLE saleslake_prd.gold_prd.fact_invoice;
