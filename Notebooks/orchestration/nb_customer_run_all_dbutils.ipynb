# %%
# %run ../bronze/nb_customer_files_bronze

# %%
dbutils.notebook.help("run")

# %%
dbutils.notebook.run("/Workspace/Users/intellibidatabricks@gmail.com/IntelliBI_Data_Engineering/Notebooks/bronze/nb_customer_files_bronze", 60,
                   {"environment": "qa"}  )

# %%
# %run ../silver/nb_customer_bronze_silver

# %%
# %run ../gold/nb_cust_silver_gold
