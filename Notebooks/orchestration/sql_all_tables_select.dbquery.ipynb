-- %%
----------------------- 1. Bronze Tables -------------------------
------------ 1. Bronze Sales ---------------------
SELECT * FROM saleslake_dev.bronze_dev.rawSales;
SELECT * FROM saleslake_qa.bronze_qa.rawSales;
SELECT * FROM saleslake_prd.bronze_prd.rawSales;

------------ 2. Bronze Customer ---------------------
SELECT * FROM saleslake_dev.bronze_dev.rawCustomer;
SELECT * FROM saleslake_qa.bronze_qa.rawCustomer;
SELECT * FROM saleslake_prd.bronze_prd.rawCustomer;


------------ 3. Bronze Discount ---------------------
SELECT * FROM saleslake_dev.bronze_dev.rawDiscount;
SELECT * FROM saleslake_qa.bronze_qa.rawDiscount;
SELECT * FROM saleslake_prd.bronze_prd.rawDiscount;


------------ 4. Bronze rawInvoice ---------------------
SELECT * FROM saleslake_dev.bronze_dev.rawInvoice;
SELECT * FROM saleslake_qa.bronze_qa.rawInvoice;
SELECT * FROM saleslake_prd.bronze_prd.rawInvoice;


----------- 5. Bronze rawRegion ---------------------
SELECT * FROM saleslake_dev.bronze_dev.rawRegion;
SELECT * FROM saleslake_qa.bronze_qa.rawRegion;
SELECT * FROM saleslake_prd.bronze_prd.rawRegion;

------------ 6. Bronze rawProduct ---------------------
SELECT * FROM saleslake_dev.bronze_dev.rawProduct;
SELECT * FROM saleslake_qa.bronze_qa.rawProduct;
SELECT * FROM saleslake_prd.bronze_prd.rawProduct;

------------ 7. Bronze rawStore ---------------------
SELECT * FROM saleslake_dev.bronze_dev.rawStore;
SELECT * FROM saleslake_qa.bronze_qa.rawStore;
SELECT * FROM saleslake_prd.bronze_prd.rawStore;

--------------------------------------------------------------------------------------------------------------
----------------------- 2. Silver Tables -------------------------
------------ 1. Silver Sales ---------------------
SELECT * FROM saleslake_dev.silver_dev.cleanedSales;
SELECT * FROM saleslake_qa.silver_qa.cleanedSales;
SELECT * FROM saleslake_prd.silver_prd.cleanedSales;

----------- 2. Silver Customer ---------------------
SELECT * FROM saleslake_dev.silver_dev.cleanedCustomer;
SELECT * FROM saleslake_qa.silver_qa.cleanedCustomer;
SELECT * FROM saleslake_prd.silver_prd.cleanedCustomer;

----------- 3. Silver Invoice ---------------------
SELECT * FROM saleslake_dev.silver_dev.cleanedInvoice;
SELECT * FROM saleslake_qa.silver_qa.cleanedInvoice;
SELECT * FROM saleslake_prd.silver_prd.cleanedInvoice;

----------- 4. Silver Region ---------------------
SELECT * FROM saleslake_dev.silver_dev.cleanedRegion;
SELECT * FROM saleslake_qa.silver_qa.cleanedRegion;
SELECT * FROM saleslake_prd.silver_prd.cleanedRegion;

----------- 5. Silver Product ---------------------
SELECT * FROM saleslake_dev.silver_dev.cleanedProduct;
SELECT * FROM saleslake_qa.silver_qa.cleanedProduct;
SELECT * FROM saleslake_prd.silver_prd.cleanedProduct;

----------- 6. Silver Store ---------------------
SELECT * FROM saleslake_dev.silver_dev.cleanedStore;
SELECT * FROM saleslake_qa.silver_qa.cleanedStore;
SELECT * FROM saleslake_prd.silver_prd.cleanedStore;

---------- 7. Silver Discount ---------------------
SELECT * FROM saleslake_dev.silver_dev.cleanedDiscount;
SELECT * FROM saleslake_qa.silver_qa.cleanedDiscount;
SELECT * FROM saleslake_prd.silver_prd.cleanedDiscount;

----------------------------------------------------------------------------------------------------
----------------------- 3. Gold Tables -------------------------
-----------1. Gold Sales ---------------------
SELECT * FROM saleslake_dev.gold_dev.refinedSales;
SELECT * FROM saleslake_qa.gold_qa.refinedSales;
SELECT * FROM saleslake_prd.gold_prd.refinedSales;

-----------2. Gold Customer ---------------------
SELECT * FROM saleslake_dev.gold_dev.refinedCustomer;
SELECT * FROM saleslake_qa.gold_qa.refinedCustomer;
SELECT * FROM saleslake_prd.gold_prd.refinedCustomer;

-----------3. Gold Invoice ---------------------
SELECT * FROM saleslake_dev.gold_dev.refinedInvoice;
SELECT * FROM saleslake_qa.gold_qa.refinedInvoice;
SELECT * FROM saleslake_prd.gold_prd.refinedInvoice;

-----------4. Gold dim_region ---------------------
SELECT * FROM saleslake_dev.gold_dev.dim_region;
SELECT * FROM saleslake_qa.gold_qa.dim_region;
SELECT * FROM saleslake_prd.gold_prd.dim_region;

-----------5. Gold dim_product ---------------------
SELECT * FROM saleslake_dev.gold_dev.dim_product;
SELECT * FROM saleslake_qa.gold_qa.dim_product;
SELECT * FROM saleslake_prd.gold_prd.dim_product;

-----------6. Gold dim_store ---------------------
SELECT * FROM saleslake_dev.gold_dev.dim_store;
SELECT * FROM saleslake_qa.gold_qa.dim_store;
SELECT * FROM saleslake_prd.gold_prd.dim_store;

-----------7. Gold dim_discount ---------------------
SELECT * FROM saleslake_dev.gold_dev.dim_discount;
SELECT * FROM saleslake_qa.gold_qa.dim_discount;
SELECT * FROM saleslake_prd.gold_prd.dim_discount;

-----------8. Gold dim_date ---------------------
SELECT * FROM saleslake_dev.gold_dev.dim_date;
SELECT * FROM saleslake_qa.gold_qa.dim_date;
SELECT * FROM saleslake_prd.gold_prd.dim_date;

-----------9. Gold fact_sales ---------------------
SELECT * FROM saleslake_dev.gold_dev.fact_sales;
SELECT * FROM saleslake_qa.gold_qa.fact_sales;
SELECT * FROM saleslake_prd.gold_prd.fact_sales;

-----------10. Gold fact_invoice ---------------------
SELECT * FROM saleslake_dev.gold_dev.fact_invoice;
SELECT * FROM saleslake_qa.gold_qa.fact_invoice;
SELECT * FROM saleslake_prd.gold_prd.fact_invoice;
