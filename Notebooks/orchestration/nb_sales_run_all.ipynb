# %%
# %run ../bronze/nb_sales_files_bronze

# %%
dbutils.notebook.run(path = "/Workspace/Users/intellibidatabricks@gmail.com/IntelliBI_Data_Engineering/Notebooks/bronze/nb_customer_files_bronze",
                     timeout_seconds=60,
                      arguments={"environment": "prd"})

# %%
dbutils.notebook.help("run")

# %%
dbutils.notebook.run("../00_Intro", 600,environment=)

# %%
# %run ../silver/nb_sales_bronze_silver

# %%
# %run ../gold/nb_sales_silver_gold
